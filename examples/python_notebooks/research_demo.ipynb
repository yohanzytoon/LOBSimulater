# %% [markdown]
# # Research Demo
# This notebook demonstrates loading the `lobpy` module and running a simple backtest.

# %%
import lobpy
# Load order book and run a minimal backtest
bt = lobpy.Backtester()
bt.set_data_csv('data/sample_l3.csv')
bt.add_market_maker()
res = bt.run()
res.sharpe, res.max_drawdown
